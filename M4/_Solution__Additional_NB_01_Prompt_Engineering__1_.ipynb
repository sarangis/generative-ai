# %% [markdown]
# # Advanced Certification Programme in Agentic and Generative AI
# ## A Programme by IISc and TalentSprint
# ### Additional Notebook: **Prompt Engineering**
#
# (Ungraded)

# %% [markdown]
# ## Objective
#
# Experience how different prompt engineering techniques can shape the quality, accuracy, and usefulness of AI outputs. The goal is to highlight how thoughtful prompt design enhances reasoning, creativity, and control compared to generic prompting.

# %% [markdown]
# ## Instructions
#
# - First, get familiar with different Prompting Techniques by following the steps given in the notebook.
#
# - Then, complete the ungraded practice task given at the end of the notebook.

# %% [markdown]
# # I. Getting Started with different Prompting Techniques

# %% [markdown]
# ## Information
#
# **Prompt** is the input you give to an AI model—a piece of text, instruction, or query that tells the model what you want it to do.
#
# ---
#
# **Prompt Engineering** is the practice of carefully designing, crafting, and refining the ***input*** ("prompts") given to generative AI models to achieve desired ***outputs***. It involves using clear language, context, and instructions to guide the AI toward producing relevant, accurate, and specific responses, much like providing a roadmap or detailed instructions to someone.
#
# ---
#
# **Elements of a Prompt**
#
# A prompt contains any of the following elements:
#
# - **Instruction** - a specific task or instruction you want the model to perform
#
# - **Context** - external information or additional context that can steer the model to better responses
#
# - **Input Data** - the input or question that we are interested to find a response for
#
# - **Output Indicator** - the type or format of the output.
#
# ---

# %% [markdown]
# ## Groq API

# %% [markdown]
# **What is Groq?**
#
# **Groq** is a technology company that builds **specialized AI hardware and software** designed to run large language models (LLMs) and other AI models **extremely fast and efficiently**, especially for **real-time inference**.
#
# This notebook demonstrates how to interact with the **OpenAI and Llama models** using Groq API.
#
# It covers the necessary steps from installing the required packages and setting up authentication to making a chat completion request and processing the response. The example prompt is designed to generate a detailed essay on a specific topic.

# %% [markdown]
# **Read the Groq API Key**
#
# Using the Groq API Key, you will have access to the OpenAI and Llama model, free of cost, under the [Free-tier](https://console.groq.com/docs/rate-limits#rate-limits).
#
# This cell retrieves the Groq API key securely stored in Google Colab's Secrets (see 'key' icon on the leftmost panel of this notebook) and sets it as an environment variable `GROQ_API_KEY`. This is a recommended practice to avoid exposing your API key directly in the code.
#
#
# * Go to https://console.groq.com/, and setup a Free account.
#
# * Create a new API by visiting: https://console.groq.com/keys
#
# * Save the key in Google Colab's Secrets
#     ```
#     Secret Name: GROQ_API_KEY
#     Secret Value: Paste your Groq api key
#     ```
#
# * Read the key and save as an environment variable `GROQ_API_KEY`

# %%
# Save the key in Colab's Secrets then load from there

import os
from google.colab import userdata

os.environ['GROQ_API_KEY'] = userdata.get('GROQ_API_KEY')

# %% [markdown]
# **Create Groq Client**
#
# This cell initializes the Groq client using the API key stored in the environment variable. This client object will be used to make API calls to OpenAI model.

# %%
# Install Groq library
# !pip -q install groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.7/141.7 kB 5.0 MB/s eta 0:00:00

# %%
from groq import Groq

# Initialize Groq client
groq_client = Groq()

# %% [markdown]
# ## **1) Zero-Shot Prompting**
#
# Large language models (LLMs) today, such as GPT-3.5 Turbo, GPT-4, and Claude 3, are tuned to follow instructions and are trained on large amounts of data. Large-scale training makes these models capable of performing some tasks in a "zero-shot" manner. Zero-shot prompting means that the prompt used to interact with the model won't contain examples or demonstrations. **The zero-shot prompt directly instructs the model to perform a task without any additional examples to steer it.**
#
# Here is one of example for text classification:
#
# Prompt:
#
# ```
# Classify the text into neutral, negative or positive.
# Text: I think the vacation is okay.
# Sentiment:
# ```
#
# ---
# ---

# %%
prompt = """Classify the text into neutral, negative or positive.
Text: I think the vacation is okay.
Sentiment:
"""

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
# Out:
# Sentiment: neutral

# %% [markdown]
# When zero-shot doesn't work, it's recommended to provide demonstrations or examples in the prompt which leads to few-shot prompting.

# %% [markdown]
# ## **2) Few-Shot Prompting**
#
# While large-language models demonstrate remarkable zero-shot capabilities, they still fall short on more complex tasks when using the zero-shot setting. Few-shot prompting can be used as a technique to enable in-context learning where we provide demonstrations in the prompt to steer the model to better performance. The demonstrations serve as conditioning for subsequent examples where we would like the model to generate a response.
#
# Here is one of example for text classification:
#
# Prompt:
#
# ```
# This is awesome! // Positive
# This is bad! // Negative
# Wow that movie was rad! // Positive
# What a horrible show! //
# ```

# %%
prompt = """This is awesome! // Positive
This is bad! // Negative
Wow that movie was rad! // Positive
What a horrible show! //
"""

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
# Out:
# Negative

# %% [markdown]
# Standard few-shot prompting works well for many tasks but is still not a perfect technique, especially when dealing with more complex reasoning tasks.
#
# When zero-shot prompting and few-shot prompting are not sufficient, it might mean that whatever was learned by the model isn't enough to do well at the task. From here it is recommended to start thinking about fine-tuning your models or experimenting with more advanced prompting techniques.

# %% [markdown]
# ## **3) Chain-of-Thought (CoT) Prompting**
#
# <img src='https://www.promptingguide.ai/_next/image?url=%2F_next%2Fstatic%2Fmedia%2Fcot.1933d9fe.png&w=1080&q=75' width=800px>
#
# [Image Source](https://arxiv.org/abs/2201.11903)
#
#
# Introduced in [Wei et al. (2022)](https://arxiv.org/abs/2201.11903), chain-of-thought (CoT) prompting enables complex reasoning capabilities through intermediate reasoning steps. You can combine it with few-shot prompting to get better results on more complex tasks that require reasoning before responding.
#
# For example:
#
# Prompt:
#
# ```
# I went to the market and bought 10 apples. I gave 2 apples to the neighbor and 2 to the repairman.
# I then went and bought 5 more apples and ate 1. How many apples did I remain with?
# Let's think step by step.
# ```

# %%
prompt = """I went to the market and bought 10 apples. I gave 2 apples to the neighbor and 2 to the repairman.
I then went and bought 5 more apples and ate 1. How many apples did I remain with?
Let's think step by step.
"""

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
# Out:
# **Step‑by‑step calculation**
#
# | Action | Apples | Result |
# |--------|--------|--------|
# | Start | — | 0 |
# | Bought 10 apples | +10 | 10 |
# | Gave 2 to neighbor | –2 | 8 |
# | Gave 2 to repairman | –2 | 6 |
# | Bought 5 more apples | +5 | 11 |
# | Ate 1 apple | –1 | **10** |
#
# **Answer:** You have **10 apples remaining**.

# %% [markdown]
# ## **4) System Prompts** $\quad$ (Assigning a Role)
#
# A system prompt is a hidden or background instruction given to an AI model that sets the rules, behavior, or persona of the AI before it responds to user queries.
#
# - It’s not usually visible to the end-user.
# - It defines how the AI should think, respond, and behave.
# - It acts like the “ground rules” or operating instructions for the AI.
#
# **Difference from User Prompt**
#
# - **System Prompt:** Defines the AI’s role, style, and boundaries. (invisible, set by developers or platform)
# - **User Prompt:** The actual question or instruction given by the user.
#
# **Why It Matters**
#
# - Ensures consistent AI behavior across users.
# - Prevents harmful, biased, or off-topic outputs.
# - Useful for persona-based AI (e.g., tutor, lawyer, doctor assistant).
#
#
# For Example:
#
# System Prompt:
# ```
# You are a very smart physics professor.
# You are great at answering questions about physics in a concise and easy to understand manner.
# When you don't know the answer to a question you admit that you don't know.
# Start your answer with `Subject:Physics :`
# ```
#
# Prompt:
# ```
# What is black body radiation?
# ```

# %%
system_prompt = """You are a very smart physics professor. \
You are great at answering questions about physics in a concise and easy to understand manner. \
When you don't know the answer to a question you admit that you don't know.
Start your answer with `Subject:Physics :`
"""

prompt = "What is black body radiation?"

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
# Out:
# Subject:Physics :
#
# Black‑body radiation is the electromagnetic radiation emitted by an idealized object that absorbs all incident radiation, regardless of frequency or angle of incidence. Because it absorbs everything, it can only emit radiation determined by its temperature. The spectrum of this emission is described by Planck’s law, which shows that as temperature rises, the peak wavelength shifts to shorter values (Wien’s displacement law) and the total emitted power increases as the fourth power of temperature (Stefan‑Boltzmann law). Real objects approximate black bodies when they have high emissivity, and the concept is fundamental in understanding thermal radiation, stellar spectra, and the development of quantum mechanics.

# %%
prompt2 = "What is Vibe Coding?"

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": prompt2}
    ]
)

print(response.choices[0].message.content)
# Out:
# Subject:Physics : I’m not familiar with the term “Vibe Coding,” and it doesn’t seem to be a standard concept in physics or in the broader scientific literature. If you can provide more context—such as the field it’s used in, a definition, or where you encountered it—I’d be happy to look into it further.

# %% [markdown]
# ## **5) Prompt Chaining**
#
# To improve the reliability and performance of LLMs, one of the important prompt engineering techniques is to ***break tasks into its subtasks***. Once those subtasks have been identified, the LLM is prompted with a subtask and then its ***response is used as input to another prompt***. This is what's referred to as prompt chaining, where a task is split into subtasks with the idea to create a chain of prompt operations.
#
# Prompt chaining is useful to accomplish complex tasks which an LLM might struggle to address if prompted with a very detailed prompt. In prompt chaining, chain prompts perform transformations or additional processes on the generated responses before reaching a final desired state.
#
# Besides achieving better performance, prompt chaining helps to boost the transparency of your LLM application, increases controllability, and reliability. This means that you can debug problems with model responses much more easily and analyze and improve performance in the different stages that need improvement.
#
# Prompt chaining is particularly useful when building LLM-powered conversational assistants and improving the personalization and user experience of your applications.

# %% [markdown]
# **For Example:** Let us consider an example to see how a large task—writing a blog post on remote work—can be broken into smaller steps using Prompt Chaining.
#
# - First, the AI generates a blog outline,
# - then expands one section into detailed text,
# - summarizes that section into concise bullet points, and
# - finally creates a persuasive call-to-action.
#
# This step-by-step approach ensures clarity, structure, and refined outputs instead of trying to get everything in a single prompt.

# %%
# Step 1 – Generate an Outline

outline_prompt = "Create a 5-point outline for a blog post on the benefits of remote work."

outline = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "user", "content": outline_prompt}
    ]
).choices[0].message.content

print(outline)
# Out:
# **5‑Point Outline: The Benefits of Remote Work**
#
# 1. **Enhanced Work‑Life Balance**
#    - Eliminates commuting time → more personal time
#    - Flexible scheduling → accommodate family and health needs
#    - Reduced workplace stress → improved mental well‑being
#
# 2. **Higher Productivity & Performance**
#    - Fewer office distractions → deeper focus periods
#    - Customizable work environment → optimal comfort and ergonomics
#    - Data‑driven evidence: remote teams often exceed output benchmarks
#
# 3. **Cost Savings for Employees & Employers**
#    - Employees save on travel, meals, and childcare
#    - Employers reduce office space, utilities, and facility maintenance
#    - Potential for lower turnover and recruitment costs
#
# 4. **Access to a Broader Talent Pool**
#    - Geographic boundaries dissolved → hire the best fit anywhere
#    - Diversity & inclusion opportunities increase
#    - Flexibility attracts top talent seeking remote or hybrid roles
#
# 5. **Positive Environmental Impact**
#    - Fewer daily commutes → reduced carbon footprint
#    - Lower office energy consumption → smaller ecological impact
#    - Encourages sustainable habits (e.g., digital over printed materials)
#
# *Use this skeleton to flesh out each point with real‑world examples, data, and actionable tips for both managers and remote workers.*

# %%
# Step 2 – Expand a Section

expand_prompt = "Expand point #2 into a 120-word explanation with real-life examples."

point2_explaination = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "user", "content": outline_prompt},
        {"role": "assistant", "content": outline},
        {"role": "user", "content": expand_prompt},
    ]
).choices[0].message.content

print(point2_explaination)

# %%
# Step 3 – Create a Summary

summary_prompt = "Summarize this section in 2 bullet points for a presentation slide."

point2_summary = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "user", "content": outline_prompt},
        {"role": "assistant", "content": outline},
        {"role": "user", "content": expand_prompt},
        {"role": "assistant", "content": point2_explaination},
        {"role": "user", "content": summary_prompt},
    ]
).choices[0].message.content

print(point2_summary)
# Out:
# - **Focused, distraction‑free output:** Remote teams eliminate office noise, enabling deeper work and higher productivity—studies show remote developers produce 30 % more commits and sales reps close 25 % more deals than in‑office peers.
# - **Customizable environments + flexible timing:** Employees set up ergonomic home offices and choose peak‑productivity hours, boosting performance while maintaining job satisfaction.

# %%
# Step 4 – Add a Call-to-Action

call_to_action_prompt = "Write a closing call-to-action encouraging companies to adopt remote work policies."

call_to_action = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "user", "content": outline_prompt},
        {"role": "assistant", "content": outline},
        {"role": "user", "content": expand_prompt},
        {"role": "assistant", "content": point2_explaination},
        {"role": "user", "content": summary_prompt},
        {"role": "assistant", "content": point2_summary},
        {"role": "user", "content": call_to_action_prompt},
    ]
).choices[0].message.content

print(call_to_action)
# Out:
# **Take the leap today—redefine the future of work.**
# Embrace remote work policies and unlock higher productivity, deeper talent pipelines, and a healthier bottom line. Start the conversation, pilot a flexible model, and watch your team thrive. Ready to make the shift? Contact us now to design a customized remote‑work strategy that delivers real results.

# %% [markdown]
# ## **6) Using an LLM to provide Prompt**
#
# Instead of framing the prompt ourself, we can ask an LLM to create a detailed prompt that can be used to get the desired response.
#
# **Example Scenario:** Suppose we want to generate a professional email, but instead of manually writing the prompt, we first ask the LLM to create a better prompt for us.

# %%
# Function to generate prompt

def generate_prompt(input):
    prompt = f"""For the given request create a detailed prompt to be fed to an LLM for response generation.
    Provide only the prompt and not the LLM response.
    Request: {input}"""

    response = groq_client.chat.completions.create(
        model="openai/gpt-oss-120b",
        messages=[
            {"role": "user", "content": prompt}
        ]
    )

    return response.choices[0].message.content

# %%
request = "write a professional email requesting a meeting with a client next week"
new_prompt = generate_prompt(request)

print(new_prompt)
# Out:
# **Prompt:**
#
# You are a business professional tasked with writing a concise, courteous, and persuasive email to a client, requesting a meeting to be held sometime next week. Follow these guidelines:
#
# 1. **Subject Line** – Include a clear and relevant subject (e.g., “Request for a Meeting Next Week – [Project/Topic]”).
#
# 2. **Greeting** – Address the client by name (e.g., “Dear [Client’s First Name],”).
#
# 3. **Opening** – Briefly re‑introduce yourself and your organization, and reference any recent interaction or relevant context that justifies the meeting.
#
# 4. **Purpose** – Clearly state the purpose of the meeting (e.g., discuss project progress, present a proposal, explore partnership opportunities).
#
# 5. **Proposed Timing** – Offer two or three specific date‑time options for the following week, while also indicating flexibility to accommodate the client’s schedule. Mention the expected duration (e.g., 30 minutes, 1 hour).
#
# 6. **Value Proposition** – Highlight the key benefits the client will gain from the meeting (e.g., insights, solutions, next steps).
#
# 7. **Call to Action** – Politely ask the client to confirm a suitable time or suggest alternatives.
#
# 8. **Closing** – End with a courteous sign‑off, your full name, title, company, and contact information (phone and email).
#
# 9. **Tone & Style** – Maintain a professional, respectful, and friendly tone. Use clear, concise language and avoid jargon.
#
# 10. **Length** – Keep the email brief (150‑200 words total).
#
# **Your task:** Using the guidelines above, compose the full email. Replace placeholders (e.g., [Client’s First Name], [Your Name], [Your Title], [Company Name], [Project/Topic], specific dates/times) with appropriate realistic examples. Ensure the email is ready to send as‑is.

# %%
email_response = groq_client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "user", "content": new_prompt}
    ]
)

print(email_response.choices[0].message.content)
# Out:
# **Subject:** Request for a Meeting Next Week – Quarterly Review of GreenTech Initiative
#
# **Dear Sarah,**
#
# I hope you’re well. I’m Michael Rivera, Business Development Manager at EcoSolutions Ltd. Following our brief call on March 15 regarding the GreenTech Initiative, I’d like to schedule a short meeting to review progress and outline next steps.
#
# The purpose of our discussion is to present the latest performance insights, address any questions you may have, and explore additional opportunities to enhance the project’s impact.
#
# Would any of the following slots work for you? (All meetings are planned for 45 minutes.)
# - Tuesday, March 31 at 10:00 AM EST
# - Wednesday, April 1 at 2:30 PM EST
# - Thursday, April 2 at 11:00 AM EST
#
# If none are convenient, I’m happy to adjust to a time that better fits your schedule.
#
# Meeting together will give you a concise update, actionable recommendations, and a clear roadmap for the next quarter, ensuring we stay on track to meet your sustainability goals.
#
# Please let me know which option suits you best, or suggest an alternative.
#
# Thank you for your time, and I look forward to our conversation.
#
# Best regards,
#
# Michael Rivera
# Business Development Manager
# EcoSolutions Ltd.
# Phone: +1 (555) 123‑4567
# Email: m.rivera@ecosolutions.com

# %% [markdown]
# ## **7) JSON Prompting**
#
# **JSON Prompting** is a technique where you instruct an AI model to return its output in **JSON (JavaScript Object Notation)** format — a structured, machine-readable way of representing data.
#
# Instead of producing free-flowing text, the model outputs information in a structured schema (with keys and values).
#
# ---
#
# **Why JSON Prompting?**
#
# - Ensures **consistent structure** for downstream systems.
#
# - Makes it easy to **parse and integrate outputs** into software, dashboards, or APIs.
#
# - Useful in **automation, reporting, and data pipelines**.
#
# ---
#
# **Why it Works?**
#
# The effectiveness of JSON Prompting it leverages how LLMs actually learn. During training, these models encounter millions of examples of structured data: API responses, configuration files, database schemas, and code documentation. JSON patterns are deeply embedded in their understanding.
#
# JSON Prompting transforms AI from an unpredictable tool into a reliable system component. Teams can build automated workflows knowing that outputs will consistently match expected formats, reducing the need for complex error handling and manual intervention.
#
# ---
#
# Consider the following example:
#
# **Traditional Prompt:**
# ```
# "Analyze this customer review and tell me about the sentiment"
# ```
#
# **JSON Prompt:**
# ```
# {
#   "task": "sentiment_analysis",
#   "input": "The product exceeded my expectations!",
#   "output_format": {
#     "sentiment": "positive|negative|neutral",
#     "confidence": "0.0-1.0",
#     "key_phrases": ["array", "of", "strings"],
#     "summary": "brief explanation"
#   }
# }
# ```

# %%
# Json Prompt example

json_prompt = """{
  "task": "sentiment_analysis",
  "input": "The product exceeded my expectations!",
  "output_format": {
    "sentiment": "positive|negative|neutral",
    "confidence": "0.0-1.0",
    "key_phrases": ["array", "of", "strings"],
    "summary": "brief explanation"
  }
}"""

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "user", "content": json_prompt}
    ]
)

# %%
output = response.choices[0].message.content
print(output)                       # <-- the output looks json but it is still a string
# Out:
# ```json
# {
#   "sentiment": "positive",
#   "confidence": 0.98,
#   "key_phrases": [
#     "exceeded my expectations"
#   ],
#   "summary": "The user expresses strong satisfaction, stating that the product performed better than anticipated."
# }
# ```

# %%
type(output)
# Out:
# str

# %%
print('\n'.join(output.split('\n')[1:-1]))
# Out:
# {
#   "sentiment": "positive",
#   "confidence": 0.98,
#   "key_phrases": [
#     "exceeded my expectations"
#   ],
#   "summary": "The user expresses strong satisfaction, stating that the product performed better than anticipated."
# }

# %%
# Convert the output string to Json (Python dictionary)

import json

try:
    parsed_output = json.loads(output)
except:
    parsed_output = json.loads('\n'.join(output.split('\n')[1:-1]))

type(parsed_output)
# Out:
# dict

# %%
parsed_output
# Out:
# {'sentiment': 'positive',
#  'confidence': 0.98,
#  'key_phrases': ['exceeded my expectations'],
#  'summary': 'The user expresses strong satisfaction, stating that the product performed better than anticipated.'}

# %%
# Now you can access fields like a dictionary
print(parsed_output["sentiment"])
print(parsed_output["confidence"])
print(parsed_output["key_phrases"])
print(parsed_output["summary"])
# Out:
# positive
# 0.98
# ['exceeded my expectations']
# The user expresses strong satisfaction, stating that the product performed better than anticipated.

# %% [markdown]
# ## **8) Dynamic Prompt Generation Using Jinja Templates**

# %% [markdown]
# **Jinja** (commonly Jinja2) is a templating engine for Python that allows you to create dynamic text or documents by combining static text with variables and logic.
#
# In simple terms, Jinja is a tool that lets you insert data and logic into text templates to generate final output dynamically.

# %% [markdown]
# **Basic Examples for Jinja Template**
#
# **Example 1:** Variable substitution

# %%
# Define a Jinja Template

from jinja2 import Template

template_str = """
Hello {{ name }}!

{{ message }}

Regards,
Support Team
"""

template = Template(template_str)

# %%
# Render the Template
output = template.render(name="Aman", message="Thanks for visiting")
print(output)
# Out:
# Hello Aman!
#
# Thanks for visiting
#
# Regards,
# Support Team

# %%
# Render the Template for different inputs
output = template.render(name="Rashi", message="We appreciate your feedback")
print(output)
# Out:
# Hello Rashi!
#
# We appreciate your feedback
#
# Regards,
# Support Team

# %% [markdown]
# **Example 2:** If-else condition

# %%
# Define a Jinja Template

from jinja2 import Template

template_str = """
Hello {{ name }}!

{% if sentiment == "positive" %}
We're glad to hear that you had a great experience!

{% elif sentiment == "negative" %}
We're sorry your experience didn't go as expected. Thanks for bringing this to our attention. We will look into it right away.

{% else %}
We appreciate your feedback.

{% endif %}

Sincerely,
Support Team
"""

template = Template(template_str)

# %%
# Render the Template
output = template.render(name="Joy", sentiment="positive")
print(output)
# Out:
# Hello Joy!
#
#
# We're glad to hear that you had a great experience!
#
#
#
# Sincerely,
# Support Team

# %%
# Render the Template for different inputs
output = template.render(name="Rashi", sentiment="negative")
print(output)
# Out:
# Hello Rashi!
#
#
# We're sorry your experience didn't go as expected. Thanks for bringing this to our attention. We will look into it right away.
#
#
#
# Sincerely,
# Support Team

# %% [markdown]
# **Example 3: Jinja + LLM Call**

# %%
# Define a Jinja Template

from jinja2 import Template

template_str = """
You are an expert {{ domain }} consultant.

Task:
{{ task }}

Context:
{{ context }}

Instructions:
{% if tone == "formal" %}
- Use professional language
{% else %}
- Use simple and friendly language
{% endif %}
- Keep the response under {{ max_words }} words
"""

# %%
# Render the Template

template = Template(template_str)

prompt = template.render(
    domain="HR",
    task="Suggest employee engagement activities",
    context="Remote teams are feeling disconnected",
    tone="formal",
    max_words=100
)

print(prompt)
# Out:
# You are an expert HR consultant.
#
# Task:
# Suggest employee engagement activities
#
# Context:
# Remote teams are feeling disconnected
#
# Instructions:
#
# - Use professional language
#
# - Keep the response under 100 words

# %%
# Send Prompt to LLM

response = groq_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
        {"role": "user", "content": prompt}
    ]
)

print(response.choices[0].message.content)
# Out:
# **Remote‑Engagement Toolkit**
#
# 1. **Virtual coffee breaks** – 15‑minute informal chats scheduled weekly.
# 2. **Team‑building workshops** – gamified problem‑solving or online escape rooms.
# 3. **Peer recognition platform** – digital shout‑outs and rotating spotlights.
# 4. **Wellness series** – guided meditation or live fitness classes.
# 5. **Skill‑share sessions** – employees present micro‑workshops on hobbies or tools.
# 6. **Quarterly virtual retreats** – immersive multi‑day events with breakout discussions.
# 7. **Mentorship pairings** – cross‑department mentorship to foster collaboration.
#
# Each activity should set clear objectives, offer inclusive timing, and track measurable engagement metrics.

# %% [markdown]
# # II. Practice Task
#
# (Ungraded)

# %% [markdown]
# Create an **AI System** that can respond to customer and internal staff queries for a Flower Delivery Network.
#
# <br>
#
# <img src='https://drive.google.com/uc?id=1SFcrbz9nVcNHtMKUqQ18uBeKx1srOrY8' width=1000px>
#
#
# **Intermediate steps:**
#
# - **Create three different AI assistants**, each specializing in a different function of the flower delivery business:
#
#     - **Order Support Assistant** – Handles customer issues like order status, delivery delays, bouquet customization, payment queries.
#
#     - **Floral Expert Assistant** – Answers questions on flower types, care instructions, bouquet recommendations, seasonal availability.
#
#     - **Logistics & Operations Assistant** – Handles driver routing, warehouse issues, delivery time estimates, packaging guidelines.
#
#     (Hint: Use Role-based System prompts. Try including Jinja templates.)
#
# - **Route incoming user queries** to the correct assistant based on the nature of the question –
# Order Support / Floral Expert / Operations.
#
#     (Hint: Use Few-shot examples + JSON classification prompting to determine the category.)
#
# - **Test the system** using sample customer and staff queries, for example:
#
#     - *Can I change the delivery time for my bouquet?*
#
#     - *Which flowers last longest in hot weather?*
#
#     - *A driver is stuck in traffic—what should be the updated delivery estimate?*

# %% [markdown]
# **DISCLAIMER:** THIS NOTEBOOK IS PROVIDED ONLY AS A REFERENCE SOLUTION NOTEBOOK FOR THE PRACTICE TASK. THERE MAY BE OTHER POSSIBLE APPROACHES/METHODS TO ACHIEVE THE SAME RESULTS.

# %%
def classify_query(user_query):

    clf_prompt = f"""
    You are an intelligent query classifier for a Flower Delivery Network.

    Your task is to classify the user query into one of the following categories:
    1. Order Support
    2. Floral Expert
    3. Operations

    Definitions:
    - Order Support: Order status, delivery delays, payment issues, bouquet customization, cancellations.
    - Floral Expert: Flower types, care tips, bouquet recommendations, seasonal availability.
    - Operations: Driver routing, delivery logistics, warehouse issues, delivery time estimates, packaging.

    Instructions:
    - Carefully analyze the query.
    - Return ONLY the category in text format and no additional text.
    - Do not include any explanation.

    Examples:
    Query: "Where is my order?"
    Output: "Order Support"

    Query: "Which flowers last longer in summer?"
    Output: "Floral Expert"

    Query: "Driver is delayed due to traffic, what should I do?"
    Output: "Operations"

    User Query:
    {user_query}
    """

    response = groq_client.chat.completions.create(
        model="openai/gpt-oss-20b",
        messages=[
            {"role": "user", "content": clf_prompt}
        ]
    )

    return response.choices[0].message.content

# %%
classify_query("Can I change the delivery time for my bouquet?")
# Out:
# 'Order Support'

# %%
classify_query("Which flowers last longer in summer?")
# Out:
# 'Floral Expert'

# %%
classify_query("Driver is delayed due to traffic, what should I do?")
# Out:
# 'Operations'

# %%
# Define a Jinja Template

from jinja2 import Template

assistant_template_str = """
{% if category == "Order Support" %}
You are an Order Support Assistant for a Flower Delivery Network.
{% elif category == "Floral Expert" %}
You are a Floral Expert Assistant.
{% elif category == "Operations" %}
You are an Operations Assistant for a Flower Delivery Network.
{% endif %}

Your role:
{% if category == "Order Support" %}
- Help customers with order-related queries.
- Be polite, empathetic, and solution-oriented.
{% elif category == "Floral Expert" %}
- Provide expert advice on flowers and bouquets.
{% elif category == "Operations" %}
- Handle logistics and operational queries.
{% endif %}

Capabilities:
{% if category == "Order Support" %}
- Order status updates
- Delivery delays
- Payment issues
- Bouquet customization
- Order modifications or cancellations
{% elif category == "Floral Expert" %}
- Flower types and meanings
- Care instructions
- Bouquet recommendations
- Seasonal availability
{% elif category == "Operations" %}
- Driver routing
- Delivery delays and estimates
- Warehouse issues
- Packaging and handling guidelines
{% endif %}

Instructions:
{% if category == "Order Support" %}
- Provide clear and helpful responses.
- If delay or issue exists, acknowledge and reassure the customer.
- Keep the tone friendly and professional.
{% elif category == "Floral Expert" %}
- Give informative and helpful answers.
- Use a friendly and knowledgeable tone.
- Provide practical suggestions when possible.
{% elif category == "Operations" %}
- Provide accurate and actionable information.
- Be concise and clear.
- Focus on resolving operational issues efficiently.
{% endif %}

User Query:
{{ user_query }}
"""

assistant_template = Template(assistant_template_str)

# %%
# Render the Template
prompt = assistant_template.render(category="Order Support", user_query="Can I change the delivery time for my bouquet?")
print(prompt)
# Out:
# You are an Order Support Assistant for a Flower Delivery Network.
#
#
# Your role:
#
# - Help customers with order-related queries.
# - Be polite, empathetic, and solution-oriented.
#
#
# Capabilities:
#
# - Order status updates
# - Delivery delays
# - Payment issues
# - Bouquet customization
# - Order modifications or cancellations
#
#
# Instructions:
#
# - Provide clear and helpful responses.
# - If delay or issue exists, acknowledge and reassure the customer.
# - Keep the tone friendly and professional.
#
#
# User Query:
# Can I change the delivery time for my bouquet?

# %%
# Render the template
prompt = assistant_template.render(category="Floral Expert", user_query="Which flowers last longer in summer?")
print(prompt)
# Out:
# You are a Floral Expert Assistant.
#
#
# Your role:
#
# - Provide expert advice on flowers and bouquets.
#
#
# Capabilities:
#
# - Flower types and meanings
# - Care instructions
# - Bouquet recommendations
# - Seasonal availability
#
#
# Instructions:
#
# - Give informative and helpful answers.
# - Use a friendly and knowledgeable tone.
# - Provide practical suggestions when possible.
#
#
# User Query:
# Which flowers last longer in summer?

# %%
# Render the template
prompt = assistant_template.render(category="Operations", user_query="Driver is delayed due to traffic, what should I do?")
print(prompt)
# Out:
# You are an Operations Assistant for a Flower Delivery Network.
#
#
# Your role:
#
# - Handle logistics and operational queries.
#
#
# Capabilities:
#
# - Driver routing
# - Delivery delays and estimates
# - Warehouse issues
# - Packaging and handling guidelines
#
#
# Instructions:
#
# - Provide accurate and actionable information.
# - Be concise and clear.
# - Focus on resolving operational issues efficiently.
#
#
# User Query:
# Driver is delayed due to traffic, what should I do?

# %%
# Function to make LLM call and get the Response

def get_response(user_query):
    category = classify_query(user_query)
    print(f"Category: {category}\n")
    formatted_prompt = assistant_template.render(category=category, user_query=user_query)
    response = groq_client.chat.completions.create(
        model="openai/gpt-oss-20b",
        messages=[
            {"role": "user", "content": formatted_prompt}
        ],
        max_tokens=500
    )
    output = response.choices[0].message.content
    return output

# %%
response = get_response("Can I change the delivery time for my bouquet?")

print(response)
# Out:
# Category: Operations
#
# Yes – you can adjust the delivery window for a bouquet. Follow these steps:
#
# 1. **Check the Order ID** – have your order number handy (usually in the confirmation email or app).
# 2. **Log in to the Delivery App or Web Portal** – go to *Orders → Your Order* and select *Change Delivery Time*.
# 3. **Choose a New Time Slot** – the system will show available windows for the delivery address.
# 4. **Confirm the Change** – you’ll receive a confirmation email/SMS once the new slot is booked.
# 5. **If the Portal is Unavailable** – call our 24‑hr support line (1‑800‑FLOWERS) or email ops@flowers.com; a representative will update the slot for you.
#
# **Note:**
# - Changes must be made at least **2 hours before the original scheduled delivery time**.
# - If the bouquet is already in transit, we’ll do our best to accommodate but can’t guarantee a new slot.

# %%
response = get_response("Which flowers last longer in summer?")

print(response)
# Out:
# Category: Floral Expert
#
# **Flowers That Keep Their Freshness in Summer Heat**
#
# When the days get hot and the humidity rises, the trick is to choose blooms that are naturally more resilient to heat and that can thrive in a warm environment. Below is a quick “summer‑stamina” list, plus a few handy tips to keep your bouquet looking gorgeous longer.
#
# | Flower | Why It Lasts Long in Summer | Care Tips |
# |--------|-----------------------------|-----------|
# | **Carnations** | They’re naturally drought‑tolerant and keep their shape. | Trim stems at a 45° angle, change water every 2‑3 days, keep in a cool spot. |
# | **Gerberas** | Dense petals hold up well in heat; they’re also resistant to common fungal issues. | Add a pinch of flower food or a tablespoon of sugar to the vase water. |
# | **Alstroemeria (Peruvian Lily)** | Their thick stems and waxy leaves resist wilting. | Store in a shaded area; avoid direct sunlight. |
# | **Delphiniums** | Strong stems and sturdy foliage help them stay upright even in heat. | Keep the vase cool and add a bit of bleach to the water (1 tsp per gallon) to keep bacteria low. |
# | **Ranunculus** | Their layered petals stay crisp, especially when stems are kept cool. | Wrap stems in damp paper towels before cutting for extra moisture retention. |
# | **Sunflowers** | Naturally built for warmth; their thick stems support the heavy petals. | Place the bouquet near a breeze but not in direct sun; add fresh water daily. |
# | **Lilies (e.g., Asiatic or Oriental)** | They’re heat tolerant and their long, sturdy stems hold up well. | Change water every 48 h, trim stems each time, keep out of direct sun. |
# | **Hibiscus (if local)** | Their large leaves retain water well, and many varieties are heat‑resistant. | Keep in a cool, shaded area and use a wide‑m

# %%
response = get_response("Driver is delayed due to traffic, what should I do?")

print(response)
# Out:
# Category: Operations
#
# **What to do when a driver is delayed by traffic**
#
# | Step | Action | Why it matters |
# |------|--------|----------------|
# | 1. **Update the dispatch system** | Enter the new estimated arrival time (EAT) and reason (traffic). | Keeps the network’s real‑time data accurate. |
# | 2. **Notify the customer** | Send a text or automated message: “Your bouquet will arrive at X : Y minutes later due to traffic.” | Keeps the customer informed and reduces complaints. |
# | 3. **Check alternate routes** | Use the routing tool or traffic feeds (e.g., Waze, Google Maps) to find a faster path. | May shave 10‑15 min off the delay. |
# | 4. **Assign a backup driver if needed** | If the delay threatens the delivery window, hand the order to the next available driver. | Maintains service reliability. |
# | 5. **Log the incident** | Note the delay time, route, and any mitigating actions in the incident log. | Useful for future route optimization and billing adjustments. |
# | 6. **Adjust the next shift schedule** | Move any non‑critical deliveries forward or postpone them slightly to free capacity. | Keeps overall fleet utilization balanced. |
# | 7. **Follow up after arrival** | Confirm delivery completion, capture customer signature, and update the system. | Closes the loop and triggers post‑delivery analytics. |
#
# **Quick checklist for the driver**
# - Keep the phone charged and connected to GPS.
# - Pull up the suggested detour on the in‑vehicle tablet.
# - Report any new road closures immediately.
#
# Implementing these steps keeps the network running smoothly and minimizes customer impact.

# %% [markdown]
# **References:**
#
# - [Prompt Engineering Guide](https://www.promptingguide.ai/)
#
# - [Is JSON Prompting a Good Strategy?](https://blog.promptlayer.com/is-json-prompting-a-good-strategy/)
#
# - [Collection of Work Prompts](https://www.aiforwork.co/)

# %% [markdown]
# ---
#
# <center>$END$</center>
#
# ---
